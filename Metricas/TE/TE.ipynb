# %%
import math
import pandas as pd
import json
import numpy as np
import matplotlib.pyplot as plt

def load_json_file(filename):
    """Carga un archivo JSON y lo retorna como diccionario."""
    try:
        with open(filename, 'r', encoding='utf-8') as file:
            return json.load(file)
    except Exception as e:
        print(f"Error al cargar el archivo {filename}: {str(e)}")
        return None

def extract_unique_courses(profesores_data):
    """Extrae las asignaturas únicas manteniendo el orden original y sumando horas."""
    asignaturas = {}
    
    for profesor in profesores_data:
        for asignatura in profesor['Asignaturas']:
            codigo = asignatura['CodigoAsignatura']
            if codigo not in asignaturas:
                asignaturas[codigo] = {
                    'CodigoAsignatura': codigo,
                    'Nombre': asignatura['Nombre'],
                    'Vacantes': asignatura['Vacantes'],
                    'Horas': asignatura['Horas']
                }
            else:
                # Sumar las horas si la asignatura aparece más de una vez
                asignaturas[codigo]['Horas'] += asignatura['Horas']
    
    return pd.DataFrame(list(asignaturas.values()))

def calculate_te(asignatura, salas_data, total_bloques):
    """Calcula el TE para una asignatura específica."""
    salas_utiles = [sala for sala in salas_data if sala['Capacidad'] >= asignatura['Vacantes']]
    bloques_disponibles = len(salas_utiles) * total_bloques
    
    if total_bloques * len(salas_data) > 0:
        te = bloques_disponibles / (total_bloques * len(salas_data))
    else:
        te = 0
        
    return {
        'Asignatura': f"{asignatura['CodigoAsignatura']} - {asignatura['Nombre']}",
        'Vacantes': asignatura['Vacantes'],
        'Horas_Semanales': asignatura['Horas'],
        'Num_salas_utiles': len(salas_utiles),
        'Bloques_disponibles': bloques_disponibles,
        'TE': round(te, 2)
    }

def calculate_te_hours(asignatura, salas_data, total_bloques):
    salas_utiles = [sala for sala in salas_data if sala['Capacidad'] >= asignatura['Vacantes']]
    bloques_disponibles = len(salas_utiles) * total_bloques
    bloques_necesarios = asignatura['Horas']
    
    if total_bloques * len(salas_data) > 0:
        # Factor base de disponibilidad
        te_base = bloques_disponibles / (total_bloques * len(salas_data))
        
        # Factor de complejidad por horas
        factor_complejidad = math.exp(-0.2 * bloques_necesarios)
        
        # TE ajustado
        te = te_base * factor_complejidad
    else:
        te = 0
        
    return {
        'Asignatura': f"{asignatura['CodigoAsignatura']} - {asignatura['Nombre']}",
        'Vacantes': asignatura['Vacantes'],
        'Horas_Semanales': asignatura['Horas'],
        'Num_salas_utiles': len(salas_utiles),
        'Bloques_disponibles': bloques_disponibles,
        'Bloques_necesarios': bloques_necesarios,
        'TE': round(te, 2)
    }

def process_all_courses(asignaturas_df, salas_data, total_bloques):
    """Procesa todas las asignaturas y calcula sus TEs."""
    return pd.DataFrame([
        calculate_te(row, salas_data, total_bloques) 
        for _, row in asignaturas_df.iterrows()
    ])

def plot_te_boxplot(resultados_df):
    plt.figure(figsize=(10, 6))
    plt.boxplot(resultados_df['TE'])
    plt.title('Distribución de TE por Asignaturas')
    plt.ylabel('TE (Tasa de Disponibilidad)')
    plt.grid(True, linestyle='--', alpha=0.7)
    
    # Add summary statistics
    stats = {
        'Media': resultados_df['TE'].mean(),
        'Mediana': resultados_df['TE'].median(),
        'Q1': resultados_df['TE'].quantile(0.25),
        'Q3': resultados_df['TE'].quantile(0.75)
    }
    
    y_pos = plt.ylim()[0]
    for i, (label, value) in enumerate(stats.items()):
        plt.text(1.3, y_pos + (i * 0.05), f'{label}: {value:.3f}', 
                horizontalalignment='left')
    
    plt.savefig('te_boxplot.png')
    plt.close()

def plot_te_scatter(resultados_df):
    """
    Crea un diagrama de dispersión que relaciona TE con el número de Vacantes.
    
    Args:
        resultados_df: DataFrame con los resultados del análisis TE
    """
    plt.figure(figsize=(12, 8))

    # Crear el scatter plot
    scatter = plt.scatter(resultados_df['Vacantes'], 
                         resultados_df['TE'],
                         alpha=0.6,
                         c='#00629B',  # Color IEEE
                         s=100)  # Tamaño de los puntos

    # Añadir línea de tendencia
    z = np.polyfit(resultados_df['Vacantes'], resultados_df['TE'], 1)
    p = np.poly1d(z)
    plt.plot(resultados_df['Vacantes'], 
             p(resultados_df['Vacantes']), 
             linestyle='--', 
             color='#A9A9A9',
             alpha=0.8)

    # Configurar el aspecto
    plt.title('Relación entre TE y Número de Vacantes', 
             fontsize=14, 
             pad=20)
    plt.xlabel('Número de Vacantes', fontsize=12)
    plt.ylabel('TE (Tasa de Disponibilidad)', fontsize=12)

    # Eliminar bordes superiores y derechos
    ax = plt.gca()
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)

    # Añadir cuadrícula
    plt.grid(True, linestyle='--', alpha=0.3)

    # Calcular y mostrar correlación
    corr = resultados_df['Vacantes'].corr(resultados_df['TE'])
    plt.text(0.02, 0.98, 
             f'Correlación: {corr:.2f}',
             transform=ax.transAxes,
             fontsize=10,
             bbox=dict(facecolor='white', alpha=0.8, edgecolor='none'))

    plt.tight_layout()
    plt.savefig('te_scatter.png', dpi=300, bbox_inches='tight')
    plt.close()

def plot_te_horizontal_bars(resultados_df):
    """
    Crea un gráfico de barras horizontal que muestra el TE de cada asignatura.
    Las asignaturas están ordenadas por TE de forma descendente.
    Incluye el número de inscritos entre paréntesis junto al nombre de la asignatura.
    
    Args:
        resultados_df: DataFrame con los resultados del análisis TE
    """
    # Ordenar el DataFrame por TE de forma descendente
    df_sorted = resultados_df.sort_values('TE', ascending=True)
    
    # Crear etiquetas combinando nombre de asignatura y vacantes
    labels = [f"{asig} ({vac})" for asig, vac in 
             zip(df_sorted['Asignatura'], df_sorted['Vacantes'])]
    
    # Configurar el tamaño de la figura basado en el número de asignaturas
    plt.figure(figsize=(15, max(8, len(labels) * 0.3)))
    
    # Crear barras horizontales
    bars = plt.barh(range(len(labels)), 
                   df_sorted['TE'],
                   color='#00629B',  # Color IEEE
                   alpha=0.7)
    
    # Configurar ejes
    ax = plt.gca()
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    
    # Configurar etiquetas del eje Y
    plt.yticks(range(len(labels)), labels, fontsize=8)
    
    # Configurar etiquetas del eje X
    plt.xlabel('TE (Tasa de Disponibilidad)', fontsize=12)
    
    # Añadir título
    plt.title('Tasa de Disponibilidad (TE) por Asignatura', 
             fontsize=14, 
             pad=20)
    
    # Añadir valores de TE al final de cada barra
    for i, bar in enumerate(bars):
        width = bar.get_width()
        plt.text(width, 
                bar.get_y() + bar.get_height()/2,
                f' {width:.2f}',
                va='center',
                fontsize=8)
    
    # Añadir grid vertical
    plt.grid(axis='x', linestyle='--', alpha=0.3)
    
    # Ajustar márgenes y layout
    plt.margins(y=0.01)
    plt.tight_layout()
    
    # Guardar figura
    plt.savefig('te_horizontal_bars.png', 
                dpi=300,
                bbox_inches='tight',
                facecolor='white')
    plt.close()


def plot_te_bubble(resultados_df):
    """
    Crea un diagrama de burbujas que relaciona TE, Vacantes y Horas semanales.
    
    Args:
        resultados_df: DataFrame con los resultados del análisis TE
    """
    plt.figure(figsize=(12, 8))

    # Normalizar el tamaño de las burbujas
    size_scale = resultados_df['Horas_Semanales'] * 20  # Factor de escala para mejor visualización

    # Crear el diagrama de burbujas
    scatter = plt.scatter(resultados_df['Vacantes'],
                         resultados_df['TE'],
                         s=size_scale,
                         c=resultados_df['Horas_Semanales'],
                         cmap='YlOrRd',
                         alpha=0.6)

    # Añadir barra de color
    cbar = plt.colorbar(scatter)
    cbar.set_label('Horas Semanales', fontsize=10)

    # Configurar el aspecto
    plt.title('Relación entre TE, Vacantes y Horas Semanales', 
             fontsize=14, 
             pad=20)
    plt.xlabel('Número de Vacantes', fontsize=12)
    plt.ylabel('TE (Tasa de Disponibilidad)', fontsize=12)

    # Eliminar bordes superiores y derechos
    ax = plt.gca()
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)

    # Añadir cuadrícula
    plt.grid(True, linestyle='--', alpha=0.3)

    # Añadir leyenda de tamaños
    legend_elements = [
        plt.scatter([], [], s=5*20, c='gray', alpha=0.4, label='5 horas'),
        plt.scatter([], [], s=10*20, c='gray', alpha=0.4, label='10 horas'),
        plt.scatter([], [], s=20*20, c='gray', alpha=0.4, label='20 horas')
    ]
    plt.legend(handles=legend_elements, 
              title='Horas Semanales',
              bbox_to_anchor=(1.15, 0),
              loc='lower right')

    plt.tight_layout()
    plt.savefig('te_bubble.png', dpi=300, bbox_inches='tight')
    plt.close()

def print_summary(resultados_df, num_salas, bloques_dia, num_dias):
    """Imprime el resumen de los resultados."""
    print("\nAnálisis de TE (Disponibilidad de Franjas Horarias para el Evento):")
    print(f"\nNúmero total de salas: {num_salas}")
    print(f"Número total de bloques por día: {bloques_dia}")
    print(f"Número total de días: {num_dias}")
    print("\nEstadísticas de TE:")
    print(f"Promedio: {resultados_df['TE'].mean():.4f}")
    print(f"Mediana: {resultados_df['TE'].median():.4f}")
    print(f"Desviación estándar: {resultados_df['TE'].std():.4f}")
    print(f"\nCorrelación entre Horas Semanales y TE: {resultados_df['Horas_Semanales'].corr(resultados_df['TE']):.4f}")
    print("\nResultados detallados:")
    print(resultados_df[['Asignatura', 'Vacantes', 'Horas_Semanales', 'Num_salas_utiles', 'TE']].to_string(index=False))

def main():
    # Cargar datos
    profesores_data = load_json_file('../../agent_input/inputOfProfesores.json')
    salas_data = load_json_file('../../agent_input/inputOfSala.json')
    
    if not profesores_data or not salas_data:
        return
    
    # Constantes
    BLOQUES_DIA = 9
    NUM_DIAS = 5
    TOTAL_BLOQUES = BLOQUES_DIA * NUM_DIAS
    
    # Procesar datos
    asignaturas_df = extract_unique_courses(profesores_data)
    resultados_df = process_all_courses(asignaturas_df, salas_data, TOTAL_BLOQUES)
    #plot_te_boxplot(resultados_df)
    plot_te_scatter(resultados_df)
    plot_te_horizontal_bars(resultados_df)
    #plot_te_bubble(resultados_df)
    
    # Generar salidas
    print_summary(resultados_df, len(salas_data), BLOQUES_DIA, NUM_DIAS)
    
    # Guardar resultados
    resultados_df.to_csv('resultados_TE.csv', index=False)

if __name__ == "__main__":
    main()
# Out:
# Análisis de TE (Disponibilidad de Franjas Horarias para el Evento):
#
# Número total de salas: 73
# Número total de bloques por día: 9
# Número total de días: 5
#
# Estadísticas de TE:
# Promedio: 0.7048
# Mediana: 0.8400
# Desviación estándar: 0.2946
#
# Correlación entre Horas Semanales y TE: -0.0376
#
# Resultados detallados:
#                              Asignatura  Vacantes  Horas_Semanales  Num_salas_utiles   TE
#   (PRI82-A) - SISTEMAS DE GESTIÓN DE CA        31               12                27 0.37
#      (IC801-A) - DIRECCION DE PROYECTOS        27                4                41 0.56
#         (INT75-I) - GESTION DE EMPRESAS        16               12                64 0.88
#            (INT91-I) - TALLER DE TITULO        20               24                61 0.84
#         (ARQ23-A) - HISTORIA Y TEORIA I        48                3                 8 0.11
#                    (ARQ31-B) - TALLER 3         4                8                73 1.00
#                    (ARQ41-B) - TALLER 4        10                8                70 0.96
#                (ARQ83-A) - TERRITORIO 4        25                3                48 0.66
#              (ARQ65-A) - CONSTRUCCION 3        18                3                63 0.86
#               (ARQ85-A) - INSTALACIONES        22                3                51 0.70
#                    (ARQ21-A) - TALLER 2        30               16                32 0.44
#    (ARQ22-A) - GEOMETRIA Y ARQUITECTURA        45                3                14 0.19
#         (ARQ56-A) - PRACTICA EN OFICINA         1                2                73 1.00
#         (ARQ96-A) - PRACTICA EN TERRENO         1                2                73 1.00
#        (INT56-J) - INGENIERIA ECONOMICA        19               12                61 0.84
#                (INT59-J) - PRODUCCION I        19               12                61 0.84
#               (INT68-I) - PRODUCCION II        20               12                61 0.84
#       (INT73-I) - PROCESOS INDUSTRIALES        20               12                61 0.84
#        (IEP3C-A) - SALUD OCUPACIONAL II         0               12                73 1.00
#   (PRI62-A) - LEGISLACIÓN DE SALUD Y SE        41               12                15 0.21
#            (PRI85-A) - TALLER DE TITULO        31               12                27 0.37
#            (IME64-A) - CINETICA QUIMICA         5                3                73 1.00
#   (IMEA2-A) - CADENA DE VALOR HIDROMETA         8                2                73 1.00
#   (PRI66-A) - TALLER DE INTEGRACIÓN PRO        41                6                15 0.21
#        (FIA52-A) - ESTADÍSTICA APLICADA        17                5                64 0.88
#               (FIA41-B) - TERMODINÁMICA        53                6                 7 0.10
#   (IME61-A) - BALANCE DE MATERIA Y ENER         5                3                73 1.00
#   (IME83-A) - PURIFICACION Y SEPARACION         8                7                73 1.00
#               (INT52-I) - TERMODINAMICA        11               12                69 0.95
#       (IC804-A) - GESTIÓN DE PRODUCCIÓN        36                4                23 0.32
#                  (IC904-A) - PRODUCCION         0                2                73 1.00
#            (ICA04-A) - TALLER DE TITULO        32                3                27 0.37
#   (ICIA3-A) - PREPARCIÓN PARA EL PROCES        12                3                68 0.93
#            (INT91-J) - TALLER DE TITULO        20               24                61 0.84
#   (FIA24-C) - INTRODUCCIÓN A LA PROGRAM        33                4                27 0.37
#       (CCI83-A) - REDES DE COMPUTADORES        21                4                52 0.71
#   (FIA24-A) - INTRODUCCIÓN A LA PROGRAM        33                4                27 0.37
#   (IC10F-A) - SEGURIDAD DE LA INFORMACI        25                4                48 0.66
#                   (PRI64-A) - ERGONOMÍA        41               12                15 0.21
#   (ICE64-A) - LABORATORIO DE ELECTRÓNIC         9                3                71 0.97
#        (ICEA6-A) - TALLER DE TITULACIÓN        10                6                70 0.96
#     (INT72-FA) - GESTION DE PERSONAS II        18               12                63 0.86
#   (PRI82-S) - SISTEMAS DE GESTIÓN DE CA        16               12                64 0.88
#            (INT91-S) - TALLER DE TITULO         6               24                73 1.00
#    (ARQA2-A) - INTRODUCCION AL PROYECTO        15                9                67 0.92
#        (INT75-FA) - GESTION DE EMPRESAS        22               12                51 0.70
#              (INT24-FA) - COMPUTACION I         8               12                73 1.00
#   (ICA44-A) - BIOQUIMICA Y MICROBIOLOGI         3                5                73 1.00
#    (ICA82-A) - TRATAMIENTO DE EMISIONES         4                3                73 1.00
#   (ICAA6-A) - CAMBIO CLIMÁTICO Y RESILE        10                3                70 0.96
#   (CCI63-A) - FUNDAMENTOS DE LENGUAJE D        21                4                52 0.71
#                (CCI82-A) - COMPILADORES         0                4                73 1.00
#                 (PRI64-DV1) - ERGONOMÍA        38               12                22 0.30
#                 (PRI64-DV2) - ERGONOMÍA        37               12                22 0.30
#               (INT51-I) - MICROECONOMIA        15               12                67 0.92
#   (IMEB9-A) - DERECHO MINERO Y AMBIENTA         5                3                73 1.00
#   (IMIA3-A) - CIERRE Y ABANDONO DE FAEN        17                2                64 0.88
#         (ICA61-A) - MECANICA DE FLUIDOS         6                5                73 1.00
#     (ICA63-A) - FENOMENOS DE TRANSPORTE         6                5                73 1.00
#            (ICAA3-A) - TALLER DE TITULO        10                6                70 0.96
#                (ARQ63-A) - TERRITORIO 3        16                3                64 0.88
#                    (ARQ91-A) - TALLER 9         3               16                73 1.00
#   (ICE82-A) - LABORATORIO DE CONTROL AU        11                3                69 0.95
#                    (ICE83-A) - ROBÓTICA        14                4                67 0.92
#   (ICEA3-A) - LABORATORIO DE CONTROL DI        12                3                68 0.93
#     (ICEA4-A) - LABORATORIO DE ROBÓTICA        12                3                68 0.93
#           (INT91-FA) - TALLER DE TITULO        24               12                49 0.67
#           (INT91-FB) - TALLER DE TITULO         9               24                71 0.97
#          (INT43-I) - TEORIA DE SISTEMAS        22               12                51 0.70
#   (PRI84-A) - TÉCNICAS DE NEGOCIACIÓN Y        31               12                27 0.37
#    (PRI83-S) - COMUNICACIÓN Y LIDERAZGO        16               12                64 0.88
#                    (INT55-S) - FINANZAS         6               12                73 1.00
#                    (ARQ71-A) - TALLER 7         7                8                73 1.00
#                    (ARQ81-A) - TALLER 8        12                8                68 0.93
#                    (INT55-I) - FINANZAS        16               12                64 0.88
#   (IMIA4-A) - SIST. DE GESTION EN SEGUR        17                3                64 0.88
#   (CCI84-A) - TALLER DE INGENIERIA DE S        19                4                61 0.84
#   (CCIA1-A) - TALLER DE INNOVACION T.I.        24                4                49 0.67
#            (CCIA5-A) - TALLER DE TITULO        28                7                40 0.55
#      (ICA64-A) - BIOTECNOLOGIA APLICADA         3                8                73 1.00
#           (PRI85-AR) - TALLER DE TITULO        21               12                52 0.71
#   (INT82-J) - DESARROLLO Y EVALUACION D        19               12                61 0.84
#   (INT82-I) - DESARROLLO Y EVALUACION D        11               12                69 0.95
#  (PRI65-AR) - VIGILANCIA EPIDEMIOLÓGICA        26               12                44 0.60
#  (PRI63-AR) - HIGIENE OCUPACIONAL APLIC        30               12                32 0.44
#                  (PRI64-AR) - ERGONOMÍA        25               12                48 0.66
#      (CCI65-A) - ANALISIS DE ALGORITMOS        20                4                61 0.84
#   (CCI95-A) - METODOLOGIA DE LA INVESTI         0                2                73 1.00
#         (IC10D-A) - ESTRUCTURA DE DATOS        17                4                64 0.88
#              (FIA53-A) - ONDAS Y ÓPTICA        23                4                50 0.68
#           (ICE44-A) - TEORÍA DE REDES I         8                4                73 1.00
#                    (INT14-J) - FISICA I        22               12                51 0.70
#                   (INT34-J) - FISICA II         1               12                73 1.00
#                 (PRO51-ON) - CÁLCULO II         5                6                73 1.00
#  (PRO52-ON) - LEGISLACIÓN DE SALUD Y SE         0                6                73 1.00
#  (PRO53-ON) - LEGISLACIÓN AMBIENTAL Y G         5                9                73 1.00
#         (PRO54-ON) - QUÍMICA INDUSTRIAL         0                6                73 1.00
#  (PRO55-ON) - LABORATORIO DE HIGIENE OC         5               12                73 1.00
#  (PRO56-ON) - TALLER DE INTEGRACIÓN INI         5                6                73 1.00
#               (INT52-S) - TERMODINAMICA        12               12                68 0.93
#         (INT61-S) - MECANICA DE FLUIDOS        12               12                68 0.93
#        (PRI61-S) - OPERACIONES UNITARIA        22               12                51 0.70
#  (PRI62-AR) - LEGISLACIÓN DE SALUD Y SE        23               12                50 0.68
#      (INT72-I) - GESTION DE PERSONAS II        17               12                64 0.88
#                 (ARQ62-A) - URBANISMO 1        18                2                63 0.86
#                 (ARQ82-A) - URBANISMO 3        22                3                51 0.70
#   (FIA14-C) - INTRODUCCIÓN A LA INGENIE        63               10                 6 0.08
#               (INT51-S) - MICROECONOMIA        10               12                70 0.96
#   (PRI81-S) - METODOLOGÍAS DE INVESTIGA        16               12                64 0.88
#  (PRI84-AR) - TÉCNICAS DE NEGOCIACIÓN Y        20               12                61 0.84
#   (INT42-S) - CONTABILIDAD Y SISTEMAS D        11               12                69 0.95
# (PRI65-DV1) - VIGILANCIA EPIDEMIOLÓGICA        38               12                22 0.30
# (PRI65-DV2) - VIGILANCIA EPIDEMIOLÓGICA        37               12                22 0.30
#         (INT43-FA) - TEORIA DE SISTEMAS        22               12                51 0.70
#              (INT68-FB) - PRODUCCION II        21               12                52 0.71
#   (CCIA4-A) - LIDERAZGO Y EMPRENDIMIENT        23                4                50 0.68
# (PRI82-EEE) - SISTEMAS DE GESTIÓN DE CA        39               12                22 0.30
# (PRI82-HHH) - SISTEMAS DE GESTIÓN DE CA        37               12                22 0.30
#   (CCIA3-A) - GESTION DE CALIDAD DE SOF        24                4                49 0.67
#    (CCI44-A) - PROGRAMACION ORIENTADA A        17                4                64 0.88
#   (INT42-J) - CONTABILIDAD Y SISTEMAS D        27               12                41 0.56
#   (INT42-I) - CONTABILIDAD Y SISTEMAS D        14               12                67 0.92
#   (ICA65-A) - SISTEMA DE INFORMACION GE         4               11                73 1.00
#         (ICA84-A) - EVALUCION AMBIENTAL         5                3                73 1.00
#                    (FIA62-B) - ECONOMÍA        33                4                27 0.37
#   (FIA81-A) - ING. ECONÓMICA Y DIRECCIÓ        36                4                23 0.32
#                    (ARQ21-B) - TALLER 2        15               16                67 0.92
#          (PRI85-EEE) - TALLER DE TITULO        38               12                22 0.30
#          (PRI85-HHH) - TALLER DE TITULO        37               12                22 0.30
# (PRI81-EEE) - METODOLOGÍAS DE INVESTIGA        38               12                22 0.30
# (PRI81-HHH) - METODOLOGÍAS DE INVESTIGA        37               12                22 0.30
#  (PRI83-EEE) - COMUNICACIÓN Y LIDERAZGO        38               12                22 0.30
#  (PRI83-HHH) - COMUNICACIÓN Y LIDERAZGO        37               12                22 0.30
#   (IC803-A) - INVESTIGACION OPERATIVA I        32                4                27 0.37
#   (ICIA1-A) - CONFIABILIDAD Y MANTENIMI        15                3                67 0.92
#   (ICA81-A) - INVESTIGACION DE OPERACIO         8                4                73 1.00
#   (FIA14-A) - INTRODUCCIÓN A LA INGENIE        67                5                 5 0.07
#   (ICAA1-A) - DESARROLLO Y GESTION DE P        10                5                70 0.96
#           (INT57-J) - GESTION AMBIENTAL        18               12                63 0.86
#                    (ARQ51-B) - TALLER 5         5                7                73 1.00
#                    (ARQ61-B) - TALLER 6         8                7                73 1.00
#   (ICA83-A) - TRAMIENTO DE RESIDUOS LIQ         6                3                73 1.00
#   (ICA94-A) - PLANIFICACION TERRITORIAL         0                0                73 1.00
#           (ICAA2-A) - GESTION AMBIENTAL         8                4                73 1.00
#       (INT64-I) - OPERACIONES UNITARIAS        12               12                68 0.93
#               (ARQ25-A) - MATEMATICAS I        46                3                 8 0.11
#             (ARQ45-A) - FISICA ESTATICA        31                3                27 0.37
#    (PRI83-A) - COMUNICACIÓN Y LIDERAZGO        31               12                27 0.37
#           (FIA42-A) - MÉTODOS NUMÉRICOS        35                4                25 0.34
#   (IC603-A) - METODOLOGIA DE LA INVESTI        28                3                40 0.55
#                    (IC802-A) - FINANZAS        25                4                48 0.66
#           (FIA42-B) - MÉTODOS NUMÉRICOS        21                4                52 0.71
#               (INT51-J) - MICROECONOMIA        27               12                41 0.56
#               (FIA41-A) - TERMODINÁMICA        48                6                 8 0.11
#     (IMI44-A) - FENOMENOS DE TRANSPORTE        31                4                27 0.37
#    (IMEA3-A) - ADMINISTRACION DE RIESGO         9                3                71 0.97
#   (PRI83-AR) - COMUNICACIÓN Y LIDERAZGO        20               12                61 0.84
#    (IC404-A) - INGENIERIA DE MATERIALES        36                4                23 0.32
#       (IC601-A) - OPERACIONES UNITARIAS        31                5                27 0.37
#        (PRI61-A) - OPERACIONES UNITARIA        46               12                 8 0.11
#    (CCI64-A) - INGENIERÍA DE REQUISITOS        12                4                68 0.93
#    (CCI64-B) - INGENIERÍA DE REQUISITOS        14                4                67 0.92
#   (PRI65-A) - VIGILANCIA EPIDEMIOLÓGICA        41               12                15 0.21
#   (ARQ26-A) - ARQUITECTURA Y MATERIALID        49                3                 8 0.11
#   (ARQC2-A) - EXPRESION GRAFICA DE PROY        11                2                69 0.95
#   (ARQC9-A) - TEMÁTICAS EMERGENTES SOBR         0                0                73 1.00
#  (PRI81-AR) - METODOLOGÍAS DE INVESTIGA        20               12                61 0.84
#   (IMI82-A) - DISEÑO DE EXPLOTACIONES A        18                3                63 0.86
#   (IMI83-A) - VENTILACIÓN DE MINAS SUBT        16                3                64 0.88
#         (IMIA2-A) - PLANEAMIENTO MINERO        15                4                67 0.92
#    (IMIC5-A) - SEMINARIO DE PREPARACIÓN         1                3                73 1.00
#         (INT61-J) - MECANICA DE FLUIDOS        28               12                40 0.55
#  (PRI66-AR) - TALLER DE INTEGRACIÓN PRO        24                6                49 0.67
#  (PRI82-AR) - SISTEMAS DE GESTIÓN DE CA        20               12                61 0.84
#       (ARQ42-A) - MEDIOS DE EXPRESION 1        27                4                41 0.56
#       (FIA33-A) - CINEMÁTICA Y DINÁMICA        35               10                25 0.34
#   (FIA43-A) - ELECTRICIDAD Y MAGNETISMO        22               10                51 0.70
#   (FIA43-B) - ELECTRICIDAD Y MAGNETISMO        39               10                22 0.30
#        (ICA85-A) - SIMULACION AMBIENTAL         0                4                73 1.00
#                   (IC604-A) - MARKETING        25                4                48 0.66
#     (IC902-A) - SISTEMAS DE INFORMACIÓN         0                2                73 1.00
#   (ICA01-A) - CREATIVIDAD, INNOVACION Y         0                4                73 1.00
#         (ICA02-A) - GESTION ESTRATEGICA         0                4                73 1.00
#         (ICE61-A) - MÁQUINAS ELÉCTRICAS         8                4                73 1.00
#   (ICEA1-A) - DISEÑO Y CONST.DE CIRCUIT        11                4                69 0.95
#   (ICEA2-A) - SISTEMAS DE CONTROL DISTR        12                4                68 0.93
#   (ICE85-A) - SISTEMAS DE COMUNICACIONE        11                4                69 0.95
#    (IMI84-A) - CREATIVIDAD INNOVACION Y        11                4                69 0.95
#            (PRI85-S) - TALLER DE TITULO        16               12                64 0.88
#           (FIA31-A) - CÁLCULO VECTORIAL        44                5                15 0.21
#    (FIA32-A) - ECUACIONES DIFERENCIALES        46                5                 8 0.11
#            (FIA21-B) - CÁLCULO INTEGRAL        43                5                15 0.21
#                    (ARQ31-A) - TALLER 3         4                8                73 1.00
#                    (ARQ41-A) - TALLER 4        10                8                70 0.96
#                   (ARQA1-A) - SEMINARIO        16               16                64 0.88
#   (IMI61-A) - CARGIO Y TRANSPORTE DE MI        12                3                68 0.93
#        (IMI64-A) - GEOLOGIA ESTRUCTURAL        18                3                63 0.86
#    (IMIC4-A) - MODELAMIENTO GEOMECÁNICO        10                3                70 0.96
#          (ICE63-A) - SISTEMAS DIGITALES         8                4                73 1.00
#              (ICE65-A) - ELECTRÓNICA II         9                4                71 0.97
#   (FIA24-F) - INTRODUCCIÓN A LA PROGRAM        34                4                27 0.37
#   (CCI66-A) - EVALUACION Y DESARROLLO D        10                4                70 0.96
#     (ICE84-A) - ELECTRÓNICA DE POTENCIA        10                4                70 0.96
#    (ICEA5-A) - PROCESAMIENTO DIGITAL DE        13                4                67 0.92
#   (PRI62-S) - LEGISLACIÓN DE SALUD Y SE        23               12                50 0.68
#                (ARQ64-A) - ESTRUCTURA 2        26                3                44 0.60
#                (ARQ84-A) - ESTRUCTURA 4        18                4                63 0.86
#   (CCI85-A) - SISTEMAS DE INFORMACION P        22                4                51 0.70
#   (CCIA2-A) - GESTIÓN DE PROCESOS DE NE        22                4                51 0.70
#   (FIA24-B) - INTRODUCCIÓN A LA PROGRAM        37                4                22 0.30
#   (FIA24-E) - INTRODUCCIÓN A LA PROGRAM        33                4                27 0.37
#        (FIA45-B) - DIBUJO DE INGENIERÍA        33                4                27 0.37
#        (FIA45-A) - DIBUJO DE INGENIERÍA        39                4                22 0.30
#        (FIA45-C) - DIBUJO DE INGENIERÍA        23                4                50 0.68
#                (ARQ24-A) - TERRITORIO I        45                3                14 0.19
#   (FIA24-D) - INTRODUCCIÓN A LA PROGRAM        32                4                27 0.37
#            (FIA21-C) - CÁLCULO INTEGRAL        38                5                22 0.30
#              (FIA22-C) - ÁLGEBRA LINEAL        47                5                 8 0.11
#                   (FIAB2-A) - INGLES II        11                2                69 0.95
#                    (FIAB1-A) - INGLES I        12                2                68 0.93
#         (FIA11-A) - CÁLCULO DIFERENCIAL        47                5                 8 0.11
#         (FIA11-B) - CÁLCULO DIFERENCIAL        43                5                15 0.21
#                     (FIA12-A) - ÁLGEBRA        36                6                23 0.32
#                     (FIA12-B) - ÁLGEBRA        37                6                22 0.30
#   (PRI63-A) - HIGIENE OCUPACIONAL APLIC        42               12                15 0.21
#      (IME46-A) - MINEROLOGIA Y GEOLOGIA        13                6                67 0.92
#   (IMI45-A) - MINEROLOGIA Y PETROGRAFIA        21               12                52 0.71
#           (IMI62-A) - GEOLOGIA DE MINAS         9                3                71 0.97
#                   (INT55-FA) - FINANZAS        22               12                51 0.70
#        (INT61-FA) - MECANICA DE FLUIDOS        14               12                67 0.92
#      (INT64-FA) - OPERACIONES UNITARIAS        12               12                68 0.93
#  (INT82-FA) - DESARROLLO Y EVALUACION D        19               12                61 0.84
#              (INT52-FB) - TERMODINAMICA         8               12                73 1.00
#              (INT52-FA) - TERMODINAMICA        13               12                67 0.92
#      (INT73-FA) - PROCESOS INDUSTRIALES        24               12                49 0.67
#              (INT51-FB) - MICROECONOMIA         9               12                71 0.97
#               (INT59-FB) - PRODUCCION I        11               12                69 0.95
#        (INT61-FB) - MECANICA DE FLUIDOS         9               12                71 0.97
#       (INT56-FB) - INGENIERIA ECONOMICA        11               12                69 0.95
#          (INT57-FA) - GESTION AMBIENTAL         9               12                71 0.97
#  (INT82-FB) - DESARROLLO Y EVALUACION D        11               12                69 0.95
#         (INT75-S) - GESTION DE EMPRESAS         6               12                73 1.00
#         (ARQ43-A) - HISTORIA Y TEORIA 3        35                3                25 0.34
#       (PRI61-AR) - OPERACIONES UNITARIA        24               12                49 0.67
#                (ARQ44-A) - TERRITORIO 2        30                3                32 0.44
#  (INT42-FA) - CONTABILIDAD Y SISTEMAS D        13               12                67 0.92
#               (INT24-S) - COMPUTACION I        10               12                70 0.96
#                    (FIA62-A) - ECONOMÍA        29                4                35 0.48
#   (PRI81-A) - METODOLOGÍAS DE INVESTIGA        31               12                27 0.37
# (PRI84-EEE) - TÉCNICAS DE NEGOCIACIÓN Y        38               12                22 0.30
# (PRI84-HHH) - TÉCNICAS DE NEGOCIACIÓN Y        37               12                22 0.30
#            (IMEB4-A) - QUÍMICA DEL AGUA         1                3                73 1.00
#                   (INT12-J) - QUIMICA I        19               12                61 0.84
#       (FIAA1-A) - DIRECCIÓN ESTRATÉGICA        32                4                27 0.37
#  (INT42-FB) - CONTABILIDAD Y SISTEMAS D         9               12                71 0.97
#      (PRI61-DV1) - OPERACIONES UNITARIA        38               12                22 0.30
#      (PRI61-DV2) - OPERACIONES UNITARIA        38               12                22 0.30
# (PRI63-DV1) - HIGIENE OCUPACIONAL APLIC        40               12                21 0.29
# (PRI63-DV2) - HIGIENE OCUPACIONAL APLIC        37               12                22 0.30
#              (INT51-FA) - MICROECONOMIA        13               12                67 0.92
#              (ARQ46-A) - CONSTRUCCION 1        31                3                27 0.37
#                    (ARQ51-A) - TALLER 5         3                8                73 1.00
#                    (ARQ61-A) - TALLER 6         8                8                73 1.00
#   (PRI66-S) - TALLER DE INTEGRACIÓN PRO        22                6                51 0.70
#   (PRI63-S) - HIGIENE OCUPACIONAL APLIC        22               12                51 0.70
#   (PRI65-S) - VIGILANCIA EPIDEMIOLÓGICA        22               12                51 0.70
#    (FIA91-A) - PREPARACIÓN Y EVALUACIÓN        10                5                70 0.96
#                   (IME82-A) - FLOTACION         9                6                71 0.97
#   (IMI63-B) - PREPARACION MECANICA DE M         5                6                73 1.00
#   (IME44-A) - ELEM.DE QUIMICA INORGANIC         9                3                71 0.97
# (PRI62-DV1) - LEGISLACIÓN DE SALUD Y SE        38               12                22 0.30
# (PRI62-DV2) - LEGISLACIÓN DE SALUD Y SE        38               12                22 0.30
# (PRI66-DV1) - TALLER DE INTEGRACIÓN PRO        38                9                22 0.30
# (PRI66-DV2) - TALLER DE INTEGRACIÓN PRO        37                9                22 0.30
#   (FIA14-B) - INTRODUCCIÓN A LA INGENIE        61                5                 6 0.08
#       (IC605-A) - GESTION DE PERSONAS I        32                5                27 0.37
#     (IC82A-A) - SUPPLY CHAIN MANAGEMENT        16                3                64 0.88
#   (ICA03-A) - SISTEMAS INTEGRADOS DE GE        40                8                21 0.29
#            (FIA21-A) - CÁLCULO INTEGRAL        36                5                23 0.32
#              (FIA22-A) - ÁLGEBRA LINEAL        49                5                 8 0.11
#              (FIA22-B) - ÁLGEBRA LINEAL        43                5                15 0.21
#                 (INT32-J) - CALCULO III        22               12                51 0.70
#                   (PRI64-S) - ERGONOMÍA        22               12                51 0.70
#                  (FIAL1-A) - INGLES III        21                4                52 0.71
#          (CCI61-A) - SISTEMAS DIGITALES         0                4                73 1.00
#   (CCI81-A) - ARQUITECTURA DE COMPUTADO        15                4                67 0.92
#               (INT24-J) - COMPUTACION I        27               12                41 0.56
#              (IME84-A) - PIROMETALURGIA        11                6                69 0.95
#   (IMI63-A) - PREPARACION MECANICA DE M        17               10                64 0.88
#               (INT52-J) - TERMODINAMICA        30               12                32 0.44
#         (INT61-I) - MECANICA DE FLUIDOS        13               12                67 0.92
#   (PRI84-S) - TÉCNICAS DE NEGOCIACIÓN Y        16               12                64 0.88
#     (ICIA5-A) - INTRODUCCIÓN A PROYECTO        16                3                64 0.88
#   (INT16-J) - ADMINISTRACION DE EMPRESA        23               12                50 0.68
